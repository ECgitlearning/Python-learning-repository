# %%
#Pandas - Written in a language called FORTRAN

import pandas as pd

df = pd.DataFrame({'ChildId':['id1', 'id2', 'id3', 'id4', 'id5'],
                   'Age first contact':[6,12,11,1,19],
                   'Gender':['M','m', 'F', '', 'F' ],
                   'Birthday':['01/01/2002', '02/02/2003', pd.NA, '03/03/2023', '06/01/2012'],
                   'Age':[5,12,11,6,2],
                   'CP Plan?':['Y', 'n', 'N', 'No', 'yES'],})
df['Birthday'] = pd.to_datetime(df['Birthday'], dayfirst=True)
df

# %%
var_1 = "words" # string
var_2 = 10 # integer
var_3 = 10.0 # float
var_4 = [10, 10.0, "10", var_3, [var_1, var_2]] # list
var_5 = {"key_1":var_1,
         "key_2":var_4} # dictionary
 
var_5["key_3"] = "Value 3"
 
print(var_5["key_1"])
print(var_5.items())
print(var_5.keys())
print(var_5.values())
# Out:
# words
# dict_items([('key_1', 'words'), ('key_2', [10, 10.0, '10', 10.0, ['words', 10]]), ('key_3', 'Value 3')])
# dict_keys(['key_1', 'key_2', 'key_3'])
# dict_values(['words', [10, 10.0, '10', 10.0, ['words', 10]], 'Value 3'])

# %%
#Pandas - Written in a language called FORTRAN
import pandas as pd #importing pandas with the alias pd
import os # allows you to use filepaths on your operation system such as # filepath = "c://shared_drive/list_9.csv" # example of reading from

filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

house_prices = pd.read_csv(filepath) #pd.read_excel() for reading excels

type(house_prices) #DataFrame pandas word for tabular data

# standard variable name for dataframes is df, # example different nsme list_1_df

# house_prices  # executes house prices could use print but not recommended

# house_prices.info() # gives table info

# house_prices.head(20) # shows top 20 rows

# house_prices.tail(10) # shows bottom 10 rows
# Out:
#               Name   Period  House price index All property types  \
# 0   United Kingdom  1980-01                                 10.11
# 1   United Kingdom  1980-02                                 10.11
# 2   United Kingdom  1980-03                                 10.11
# 3   United Kingdom  1980-04                                 10.51
# 4   United Kingdom  1980-05                                 10.51
# 5   United Kingdom  1980-06                                 10.51
# 6   United Kingdom  1980-07                                 10.94
# 7   United Kingdom  1980-08                                 10.94
# 8   United Kingdom  1980-09                                 10.94
# 9   United Kingdom  1980-10                                 10.96
# 10  United Kingdom  1980-11                                 10.96
# 11  United Kingdom  1980-12                                 10.96
# 12  United Kingdom  1981-01                                 10.98
# 13  United Kingdom  1981-02                                 10.98
# 14  United Kingdom  1981-03                                 10.98
# 15  United Kingdom  1981-04                                 11.28
# 16  United Kingdom  1981-05                                 11.28
# 17  United Kingdom  1981-06                                 11.28
# 18  United Kingdom  1981-07                                 11.46
# 19  United Kingdom  1981-08                                 11.46
#
#     Average price All property types  \
# 0                              19273
# 1                              19273
# 2                              19273
# 3                              20044
# 4                              20044
# 5                              20044
# 6                              20857
# 7                              20857
# 8                              20857
# 9                              20897
# 10                             20897
# 11                             20897
# 12                             20938
# 13                             20938
# 14                             20938
# 15                             21507
# 16                             21507
# 17                             21507
# 18                             21852
# 19                             21852
#
#     Percentage change (monthly) All property types  \
# 0                                             3.94
# 1                                             3.94
# 2                                             3.94
# 3                                             4.00
# 4                                             4.00
# 5                                             4.00
# 6                                             4.05
# 7                                             4.05
# 8                                             4.05
# 9                                             0.19
# 10                                            0.19
# 11                                            0.19
# 12                                            0.19
# 13                                            0.19
# 14                                            0.19
# 15                                            2.72
# 16                                            2.72
# 17                                            2.72
# 18                                            1.61
# 19                                            1.61
#
#     Percentage change (yearly) All property types
# 0                                           28.59
# 1                                           28.59
# 2                                           28.59
# 3                                           24.15
# 4                                           24.15
# 5                                           24.15
# 6                                           19.98
# 7                                           19.98
# 8                                           19.98
# 9                                           12.71
# 10                                          12.71
# 11                                          12.71
# 12                                           8.64
# 13                                           8.64
# 14                                           8.64
# 15                                           7.29
# 16                                           7.29
# 17                                           7.29
# 18                                           4.77
# 19                                           4.77

# %%
import pandas as pd #importing pandas with the alias pd

# filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/ChildIdentifiers.csv"
filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

ci = pd.read_csv(filepath) # need to check this CI code as it is not working, its some shortcut to the filepath

# print(type(ci))
# print(ci.info())

# ci.tail()

# %%
# Pandas - Written in a language called FORTRAN
import pandas as pd #importing pandas with the alias pd
import os # allows you to use filepaths on your operation system such as # filepath = "c://shared_drive/list_9.csv" # example of reading from

filepath = r"https://raw.githubusercontent.com/data-to-insight/ERN-sessions/main/data/1980%202023%20average%20house%20prices.csv"

house_prices = pd.read_csv(filepath) #pd.read_excel() for reading excels

type(house_prices) #DataFrame pandas word for tabular data

# standard variable name for dataframes is df, # example different nsme list_1_df

# house_prices  # executes house prices could use print but not recommended

# house_prices.info() # gives table info

# house_prices.head(20) # shows top 20 rows

# house_prices.tail(10) # shows bottom 10 rows
 
# datetime objects
# format argument for datetimes strfstimes
house_prices["Period_dt"] = pd.to_datetime(house_prices["Period"], format="%Y-%m")
house_prices["Period_dt"].info() # check type has changed
house_prices["Period_dt"]
# 01/01/2025 %d/%m%Y
# 01/01/25 %d/%m/%y
# 30-12-2025 %d-%m-%Y
# 30122025 %d%m%Y
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 523 entries, 0 to 522
# Series name: Period_dt
# Non-Null Count  Dtype
# --------------  -----
# 523 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 4.2 KB
# 0     1980-01-01
# 1     1980-02-01
# 2     1980-03-01
# 3     1980-04-01
# 4     1980-05-01
#          ...
# 518   2023-03-01
# 519   2023-04-01
# 520   2023-05-01
# 521   2023-06-01
# 522   2023-07-01
# Name: Period_dt, Length: 523, dtype: datetime64[ns]

# %%
ci["PersonBirthDate_dt"] = pd.to_datetime(ci["PersonBirthDate"], format="%Y-%m-%d")
ci["ExpectedPersonBirthDate_dt"] = pd.to_datetime(ci["ExpectedPersonBirthDate"], format="%Y-%m-%d")

ci["PersonDeathDate_dt"] = pd.to_datetime(ci["PersonDeathDate"], format="%Y-%m-%d", errors="coerce")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7096, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'PersonBirthDate'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 ci["PersonBirthDate_dt"] = pd.to_datetime(ci["PersonBirthDate"], format="%Y-%m-%d")
#       2 ci["ExpectedPersonBirthDate_dt"] = pd.to_datetime(ci["ExpectedPersonBirthDate"], format="%Y-%m-%d")
#       4 ci["PersonDeathDate_dt"] = pd.to_datetime(ci["PersonDeathDate"], format="%Y-%m-%d", errors="coerce")
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/frame.py:4107, in DataFrame.__getitem__(self, key)
#    4105 if self.columns.nlevels > 1:
#    4106     return self._getitem_multilevel(key)
# -> 4107 indexer = self.columns.get_loc(key)
#    4108 if is_integer(indexer):
#    4109     indexer = [indexer]
#
# File ~/.local/lib/python3.12/site-packages/pandas/core/indexes/base.py:3819, in Index.get_loc(self, key)
#    3814     if isinstance(casted_key, slice) or (
#    3815         isinstance(casted_key, abc.Iterable)
#    3816         and any(isinstance(x, slice) for x in casted_key)
#    3817     ):
#    3818         raise InvalidIndexError(key)
# -> 3819     raise KeyError(key) from err
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
#    3824     self._check_indexing_error(key)
#
# KeyError: 'PersonBirthDate'
